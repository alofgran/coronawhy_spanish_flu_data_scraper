# %% [markdown]
# # Setup
#
# Please install  poppler in the conda environment by using `sudo apt-get install poppler-utils`

# %%
#Point to file location on Google Drive
# !sudo apt-get install poppler-utils
# !pip install pdf2image 
import os
from google.colab import drive
from pdf2image.exceptions import (
PDFInfoNotInstalledError,
PDFPageCountError,
PDFSyntaxError
)
 
import subprocess 
import time
import warnings
from pdf2image import convert_from_path
from PIL import Image
Image.MAX_IMAGE_PIXELS = None
warnings.filterwarnings("ignore")
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.62.0-2ubuntu2.10).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from pdf2image) (7.0.0)

# %% [markdown]
# # Setting up the path

# %%
drive.mount('/content/gdrive', force_remount=True)
root = os.getcwd()
download_destination = 'gdrive/My Drive/COVID-19/data/spanish_flu_pdf'
cwd = os.path.join(root, download_destination)
os.chdir(cwd)
print('Current working directory: ', os.getcwd())
# Out:
# Mounted at /content/gdrive
# Current working directory:  /content/gdrive/My Drive/COVID-19/data/spanish_flu_pdf

# %% [markdown]
# # Removing the unwanted character
#
# we used word tokenizer to split the PDF'S names to a list

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')

list_pdf = "dir *.pdf"
shell_command = subprocess.check_output(list_pdf, shell=True)
shell =  shell_command.decode('utf-8')
shell = word_tokenize(shell)

print(shell)

# !rm *.pdf
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['sn84022770_19181011_7.pdf', 'sn87096017_19181121_5.pdf', 'sn84022770_19181025_10.pdf', 'sn87096037_19190213_2.pdf', 'sn84022770_19181101_1.pdf', 'sn87096037_19200408_9.pdf', 'sn84022770_19181101_4.pdf', 'sn87096040_19181017_5.pdf', 'sn84023963_19200723_6.pdf', 'sn87096040_19181107_4.pdf', 'sn84024779_19181114_4.pdf', 'sn88056024_19190130_8.pdf', 'sn84024779_19181121_1.pdf', 'sn88056024_19190302_18.pdf', 'sn84024808_19190504_27.pdf', 'sn88056024_19190406_11.pdf', 'sn84024808_19200128_6.pdf', 'sn88056024_19191006_4.pdf', 'sn84024808_19200307_6.pdf', 'sn88056024_19191116_20.pdf', 'sn84025841_19181019_6.pdf', 'sn88056093_19190912_4.pdf', 'sn84025841_19181102_4.pdf', 'sn88056093_19191024_4.pdf', 'sn84025842_19181107_2.pdf', 'sn88056093_19200319_4.pdf', 'sn84026688_19181003_3.pdf', 'sn88056093_19201015_6.pdf', 'sn84026688_19181010_3.pdf', 'sn88056159_19190129_3.pdf', 'sn84026688_19181017_3.pdf', 'sn88056159_19200414_3.pdf', 'sn84026688_19181128_4.pdf', 'sn88061179_19181120_2.pdf', 'sn84026688_19181226_3.pdf', 'sn88061179_19181127_4.pdf', 'sn84026749_19190113_15.pdf', 'sn88061179_19181204_1.pdf', 'sn84026749_19190115_19.pdf', 'sn88064020_19190522_10.pdf', 'sn84026749_19191103_6.pdf', 'sn88064055_19181010_5.pdf', 'sn84026749_19201215_22.pdf', 'sn88064057_19200410_6.pdf', 'sn84026758_19190927_6.pdf', 'sn88064094_19190920_4.pdf', 'sn84026820_19181012_1.pdf', 'sn88
# %% [markdown]
# # PDF2Image Conversion
# using PDF2Image library, converted the LOC pdf's to image(JPEG) format to pass on to the ocr

# %%
#Make new directory to store jpegs in
# !mkdir 'spanish_flu_jpg' -p

output_folder='spanish_flu_jpg' #in the current working directory

#Convert PDFs to Jpeg
initiation_time = time.time()
for paper in shell[:10]:
    print(paper)
    pages = convert_from_path(i, 300)
    for page in pages:
        print(page)
        start_time = time.time()
        #fname = f"{root}/SpanishFlu/"
        name = str(i[:-4])+".jpeg"
        #doc_dir = os.path.join(fname, name)
        #f#iles = open(doc_dir,'w')
        page.save('/'.join(('spanish_flu_jpg', name)),"JPEG")
        print (f"Time taken for {i}:" + str(time.time() - start_time))
# Out:
# sn84022770_19181011_7.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC310F0>
# Time taken for sn87096040_19181107_4.pdf:1.2722280025482178
# sn87096017_19181121_5.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC314E0>
# Time taken for sn87096040_19181107_4.pdf:1.284724473953247
# sn84022770_19181025_10.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC312B0>
# Time taken for sn87096040_19181107_4.pdf:1.230499029159546
# sn87096037_19190213_2.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC31EB8>
# Time taken for sn87096040_19181107_4.pdf:1.2556736469268799
# sn84022770_19181101_1.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC318D0>
# Time taken for sn87096040_19181107_4.pdf:1.2766225337982178
# sn87096037_19200408_9.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC316A0>
# Time taken for sn87096040_19181107_4.pdf:1.2672934532165527
# sn84022770_19181101_4.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC31240>
# Time taken for sn87096040_19181107_4.pdf:1.266493320465088
# sn87096040_19181017_5.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC311D0>
# Time taken for sn87096040_19181107_4.pdf:1.2652587890625
# sn84023963_19200723_6.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC31D68>
# Time taken for sn87096040_19181107_4.pdf:1.2702155113220215
# sn87096040_19181107_4.pdf
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4891x6702 at 0x7F354AC31390>
# Time taken for sn87096040_19181107_4.pdf:1.2953803539276123

# %%
#Another variation of the code above: 
initiation_time = time.time()
for paper in shell[:3]:
    print(paper)
    start_time = time.time()
    filename = paper.replace('.pdf', '')
    article = convert_from_path(paper, 
                                dpi=300, 
                                # thread_count=8, #Doesn't seem to have any effect on processing times
                                output_folder=output_folder, 
                                # output_file=filename,
                                fmt='jpg')
    
    print(f"Time taken for {paper}: " + str(time.time() - start_time))

print("the process took {}".format(str(time.time() - initiation_time)))
# Out:
# sn84022770_19181011_7.pdf
# Time taken for sn84022770_19181011_7.pdf: 2.2134549617767334
# sn87096017_19181121_5.pdf
# Time taken for sn87096017_19181121_5.pdf: 1.451253890991211
# sn84022770_19181025_10.pdf
# Time taken for sn84022770_19181025_10.pdf: 2.098919630050659
# the process took 5.772410869598389
